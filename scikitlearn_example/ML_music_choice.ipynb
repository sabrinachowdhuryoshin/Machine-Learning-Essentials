# %% [markdown]
# #### 1. Import the data

# %%
import pandas as pd

music_data = pd.read_csv('music.csv')
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# #### 2. Split the Data into 'Training'/'Test' sets

# %%
## segregate the input and output data sets

input_data = music_data.drop(columns = ['genre'])
output_data = music_data['genre']

print(input_data)
print(output_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3068/2433142440.py in <module>
#       2
#       3 input_data = music_data.drop(columns = ['genre'])
# ----> 4 output_data = music_data(['genre'])
#       5
#       6 print(input_data)
#
# TypeError: 'DataFrame' object is not callable
